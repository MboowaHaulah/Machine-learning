# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('titanic.csv')

# %%
#FOR DISPLAY
import seaborn as sns
import pandas as pd

pd.options.display.max_columns = 50

# Set the plot style
sns.set(style='darkgrid')

# Function to add borders to DataFrame
def add_borders(val):
    return 'border: 1px solid black'

# Apply the styling function to the DataFrame
styled_df = df.head(5).style.applymap(add_borders)

# Set the color for the axes' facecolor
sns.set(rc={'axes.facecolor': '#616E7C'})

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# ...

# %%
# Set the color for the axes' facecolor
sns.set(rc={'axes.facecolor':'#616E7C'})
#sns.set(style='darkgrid',rc={'axes,facecolor':'#616E7C'})

# %%
#IGNORE WARNINGS
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')


print(df.to_string())
# Out:
#      PassengerId  Survived  Pclass                                                                                Name     Sex    Age  SibSp  Parch              Ticket      Fare            Cabin Embarked
# 0              1         0       3                                                             Braund, Mr. Owen Harris    male  22.00      1      0           A/5 21171    7.2500              NaN        S
# 1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.00      1      0            PC 17599   71.2833              C85        C
# 2              3         1       3                                                              Heikkinen, Miss. Laina  female  26.00      0      0    STON/O2. 3101282    7.9250              NaN        S
# ...

# %%
import pandas as pd

print(pd.options.display.max_rows)
# Out:
# 60

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')

print(df.head(10))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
x = data.iloc[:,:-1].values

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')

print(df.tail(5))
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
#remove empty cells
import pandas as pd

df = pd.read_csv('titanic.csv')

new_df = df.dropna()

print(new_df.to_string())
# Out:
#      PassengerId  Survived  Pclass                                                                                Name     Sex    Age  SibSp  Parch             Ticket      Fare            Cabin Embarked
# 1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.00      1      0           PC 17599   71.2833              C85        C
# 3              4         1       1                                        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1      0             113803   53.1000             C123        S
# 6              7         0       1                                                             McCarthy, Mr. Timothy J    male  54.00      0      0              17463   51.8625              E46        S
# ...

# %%
#remove null values
import pandas as pd

df = pd.read_csv('titanic.csv')

df.dropna(inplace = True)

print(df.to_string())
# Out:
#      PassengerId  Survived  Pclass                                                                                Name     Sex    Age  SibSp  Parch             Ticket      Fare            Cabin Embarked
# 1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.00      1      0           PC 17599   71.2833              C85        C
# 3              4         1       1                                        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1      0             113803   53.1000             C123        S
# 6              7         0       1                                                             McCarthy, Mr. Timothy J    male  54.00      0      0              17463   51.8625              E46        S
# ...

# %%
#replace empty cells with 100
import pandas as pd

df = pd.read_csv('titanic.csv')

df.fillna(100, inplace = True)

# %%
#replace with mean
import pandas as pd

df = pd.read_csv('titanic.csv')

x = df["Age"].mean()

df["Age"].fillna(x, inplace = True)

# %%
#remove rows with null values
df.dropna(subset=['Age'], inplace = True)

# %%
#Replace wrong data
for x in df.index:
  if df.loc[x, "Age"] > 50:
    df.loc[x, "Age"] = 50

# %%
#Print duplicates
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.drop_duplicates(inplace = True)

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('titanic.csv')

df.plot()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('titanic.csv')

df.plot(kind = 'scatter', x = 'Age', y = 'Fare')

plt.show()

# %%
y = data['Survived']

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.Age.value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
#ML TRAIN AND TEST
#CREATE LOGISTIC REGRESSSION 

y=df.Age.values
x_data=df.drop(['Age'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x_data,y,test_size=0.33,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((596, 11), (295, 11))

# %%
X_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
X_train.head()
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 6              7         0       1                 McCarthy, Mr. Timothy J
# 718          719         0       3                     McEvoy, Mr. Michael
# 685          686         0       2  Laroche, Mr. Joseph Philippe Lemercier
# 73            74         0       3             Chronopoulos, Mr. Apostolos
# 882          883         0       3            Dahlberg, Miss. Gerda Ulrika
#
#         Sex  SibSp  Parch         Ticket     Fare Cabin Embarked
# 6      male      0      0          17463  51.8625   E46        S
# 718    male      0      0          36568  15.5000   NaN        Q
# 685    male      1      2  SC/Paris 2123  41.5792   NaN        C
# 73     male      1      0           2680  14.4542   NaN        C
# 882  female      0      0           7552  10.5167   NaN        S

# %%
X_test.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 709          710         1       3
# 439          440         0       2
# 840          841         0       3
# 720          721         1       2
# 39            40         1       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 709  Moubarek, Master. Halim Gonios ("William George")    male      1      1
# 439             Kvillner, Mr. Johan Henrik Johannesson    male      0      0
# 840                        Alhomaki, Mr. Ilmari Rudolf    male      0      0
# 720                  Harper, Miss. Annie Jessie "Nina"  female      0      1
# 39                         Nicola-Yarred, Miss. Jamila  female      1      0
#
#                Ticket     Fare Cabin Embarked
# 709              2661  15.2458   NaN        C
# 439        C.A. 18723  10.5000   NaN        S
# 840  SOTON/O2 3101287   7.9250   NaN        S
# 720            248727  33.0000   NaN        S
# 39               2651  11.2417   NaN        C

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
import pandas as pd

numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df[numeric_columns])
scaled_df = pd.DataFrame(scaled_data, columns=numeric_columns)
print(scaled_df.head())
# Out:
#    PassengerId  Survived    Pclass       Age     SibSp     Parch      Fare
# 0    -1.730108 -0.789272  0.827377 -0.530377  0.432793 -0.473674 -0.502445
# 1    -1.726220  1.266990 -1.566107  0.571831  0.432793 -0.473674  0.786845
# 2    -1.722332  1.266990  0.827377 -0.254825 -0.474545 -0.473674 -0.488854
# 3    -1.718444  1.266990 -1.566107  0.365167  0.432793 -0.473674  0.420730
# 4    -1.714556 -0.789272  0.827377  0.365167 -0.474545 -0.473674 -0.486337

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
import pandas as pd


numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df[numeric_columns])
scaled_df = pd.DataFrame(scaled_data, columns=numeric_columns)
print(scaled_df.head())
# Out:
#    PassengerId  Survived    Pclass       Age     SibSp     Parch      Fare
# 0    -1.730108 -0.789272  0.827377 -0.530377  0.432793 -0.473674 -0.502445
# 1    -1.726220  1.266990 -1.566107  0.571831  0.432793 -0.473674  0.786845
# 2    -1.722332  1.266990  0.827377 -0.254825 -0.474545 -0.473674 -0.488854
# 3    -1.718444  1.266990 -1.566107  0.365167  0.432793 -0.473674  0.420730
# 4    -1.714556 -0.789272  0.827377  0.365167 -0.474545 -0.473674 -0.486337
